# %%
from pathlib import Path

road_dir = Path.home() / "icidea_llm_ids" / "data" / "ROAD"

# Read first 10 lines of ambient log
print("AMBIENT LOG FORMAT:")
print("="*60)
with open(road_dir / "ambient_dyno_drive_basic_short.log", "r") as f:
    for i, line in enumerate(f):
        if i >= 10:
            break
        print(repr(line.strip()))

print()
print("ATTACK LOG FORMAT (accelerator):")
print("="*60)
with open(road_dir / "accelerator_attack_drive_1.log", "r") as f:
    for i, line in enumerate(f):
        if i >= 10:
            break
        print(repr(line.strip()))

print()
print("FUZZING LOG FORMAT:")
print("="*60)
with open(road_dir / "fuzzing_attack_1.log", "r") as f:
    for i, line in enumerate(f):
        if i >= 10:
            break
        print(repr(line.strip()))
# Out:
# AMBIENT LOG FORMAT:
# ...
# '(1030000000.000000) can0 162#00080003EA11F4CE'
# '(1030000000.000002) can0 0A7#0010FA27012B90A0'
# '(1030000000.000003) can0 FFF#0000000000000000'
# '(1030000000.000004) can0 498#84002000F3800009'
# '(1030000000.001017) can0 464#0002400000901A54'
# '(1030000000.001018) can0 577#000008000000013C'
# '(1030000000.001019) can0 69D#E49B5020C69178B1'
# '(1030000000.001020) can0 230#F4000002EC001600'
# '(1030000000.002180) can0 3B9#2004720000005C42'
# '(1030000000.003805) can0 69E#0440047E1FC01522'
#
# ATTACK LOG FORMAT (accelerator):
# ...
# '(1290000000.000000) can0 585#0040000000020018'
# '(1290000000.000002) can0 354#1FFF40000003C580'
# '(1290000000.000003) can0 5E1#893FE0070A000080'
# '(1290000000.000004) can0 28B#0000000000000000'
# '(1290000000.000994) can0 0A7#005108E5112A00A0'
# '(1290000000.000996) can0 2D2#0000500000000000'
# '(1290000000.001001) can0 69E#0440048320001540'
# '(1290000000.001002) can0 125#9080FF9F41EE5960'
# ...
