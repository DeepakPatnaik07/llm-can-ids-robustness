# %% [markdown]
# Question 1: What exact SecureBERT input/layer did SHAP explain?
# SHAP explained the input token level using the final classifier output (probability scores for 5 classes). Specifically we used shap.Explainer with a Text masker — it masks input tokens and measures how the output probability changes.

# %%
# In your local SHAP notebook
print(f"SHAP explainer type: {type(explainer)}")
print(f"SHAP masker type: {type(masker)}")

# Show what a SHAP value object contains
sv = baseline_shap_values[0]
print(f"\nSHAP values shape: {sv.values.shape}")
print(f"  Dimension 0: number of inputs (1 text)")
print(f"  Dimension 1: number of tokens")
print(f"  Dimension 2: number of classes (5)")
print(f"\nTokens for first window:")
print(sv.data[0][:20])
print(f"\nSHAP values for first 5 tokens (all 5 classes):")
print(sv.values[0][:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # In your local SHAP notebook
# ----> 2 print(f"SHAP explainer type: {type(explainer)}")
#       3 print(f"SHAP masker type: {type(masker)}")
#       4
#       5 # Show what a SHAP value object contains
#
# NameError: name 'explainer' is not defined
